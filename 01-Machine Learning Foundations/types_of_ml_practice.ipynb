# %% [markdown]
# # Types of Machine Learning — Practice Problems
#
# Goal: for each scenario below, you decide **which type of ML fits** (Supervised-Classification, Supervised-Regression, Unsupervised-Clustering, Unsupervised-Dimensionality Reduction, or Reinforcement Learning), write down *why*, and then write a small Python snippet that represents the shape of that problem (the data you'd have, not a full trained model — we haven't learned algorithms yet).
#
# Read `theory.md` in this folder first (Section 1: Types of Machine Learning) before attempting these.
#
# For each problem:
# 1. Read the scenario.
# 2. Answer in the markdown cell: which ML type fits, and why (one sentence, tie it back to "do I have labels? what am I predicting/finding?").
# 3. Fill in the code cell — a tiny Python representation of the *shape* of the problem (e.g. a small labeled dataset for supervised problems, an unlabeled one for unsupervised, or agent/action/reward variables for RL). Not a real trained model — just enough Python to show you understand what data supervised/unsupervised/RL problems actually look like.

# %% [markdown]
# ---
# ## Problem 1 — Email Spam Filter
#
# You have 500 past emails. For each one, you know the sender, subject line, and word count — **and** whether it was actually spam or not (marked by users at the time).
#
# You want to predict: for a brand-new incoming email, is it spam or not?
#
# **Your answer (fill in):**
# - ML type: ?
# - Why: ?

# %%
# Represent the SHAPE of this problem in Python — not a trained model, just the data shape.
# Hint: you have FEATURES (sender, subject, word_count) AND a LABEL (is_spam) for each past email.
# Build a small list of dicts (or similar) representing e.g. 4 past emails with their label,
# then write ONE new, unlabeled email you'd want to predict on.

# your code here

# %% [markdown]
# ---
# ## Problem 2 — Predicting House Prices
#
# You have historical data for 1,000 houses sold in your city: square footage, number of bedrooms, distance to city center, and the **actual price they sold for**.
#
# You want to predict: what will a new house (not yet sold) likely sell for?
#
# **Your answer (fill in):**
# - ML type: ?
# - Why: ?

# %%
# Represent the shape of this problem.
# Hint: what's different about the "label" here compared to Problem 1 (spam)?
# Is "price" a category or a number? That decides which supervised sub-type this is.

# your code here

# %% [markdown]
# ---
# ## Problem 3 — Grouping Customers with No Labels
#
# An online store has data for 2,000 customers: average order value, number of orders per month, and days since last order. Nobody has ever labeled these customers into "types" — there's no `customer_type` column at all.
#
# The marketing team wants to send different promotions to different "kinds" of customers, but first someone needs to figure out what natural customer groups even exist in the data.
#
# **Your answer (fill in):**
# - ML type: ?
# - Why: ?

# %%
# Represent the shape of this problem.
# Hint: compare this dataset to Problem 1/2 — what column is MISSING here that
# was present there? That missing piece is exactly why this isn't supervised learning.

# your code here

# %% [markdown]
# ---
# ## Problem 4 — Too Many Columns
#
# A product dataset has 300 columns describing each product (dimensions in cm, dimensions in inches, weight in kg, weight in lbs, dozens of near-duplicate/redundant measurement columns, plus genuinely useful ones). You want to simplify this down to a much smaller set of columns that still captures most of the useful information, mainly to make later modeling faster and less noisy.
#
# **Your answer (fill in):**
# - ML type: ?
# - Why: ?

# %%
# Represent the shape of this problem.
# Hint: you don't need real data here — just show, with a comment,
# "300 columns in" -> "~15 columns out" and explain in a comment WHY this
# is unsupervised rather than supervised (what's missing again?).

# your code here

# %% [markdown]
# ---
# ## Problem 5 — A Delivery Robot Learning a Route
#
# A warehouse robot needs to learn the fastest path to move packages from the receiving dock to the correct shelf. There's no dataset of "correct paths" to learn from upfront. Instead, every time the robot completes a delivery, it's told how long the trip took (faster = better). Over thousands of attempts, it should get better at choosing routes.
#
# **Your answer (fill in):**
# - ML type: ?
# - Why: ?

# %%
# Represent the shape of this problem.
# Hint: this one doesn't have a clean "dataset" like the others.
# Instead, define the 4 RL ingredients from theory.md Section 5 as Python variables:
#   agent, environment, action (example one), reward (example one)
# e.g. agent = "warehouse robot"  ... etc.

# your code here

# %% [markdown]
# ---
# ## Problem 6 — The Tricky One (mixed signals)
#
# A bank has past loan applications, each with income, credit score, loan amount, and whether the loan was **eventually repaid or defaulted**.
#
# They want a system that looks at a **new** applicant and predicts: will they likely repay or default?
#
# Also — before building that, a data scientist first ran a separate exploration step, grouping *existing* customers by spending behavior alone (no repaid/defaulted info used in that step at all), just to understand the customer base better.
#
# **Your answer (fill in) — there are TWO ML problems described here, answer for each:**
# - The loan repay/default prediction: ML type? Why?
# - The earlier customer grouping step: ML type? Why?

# %%
# Represent the shape of BOTH problems separately in Python.
# Hint: same underlying customers, but two different problems --
# one has a label column in play, the other deliberately does not use one.

# your code here

# %% [markdown]
# ---
# ## Self-check (after you fill in your answers)
#
# | Problem | Expected ML type |
# |---|---|
# | 1. Spam filter | Supervised — Classification |
# | 2. House prices | Supervised — Regression |
# | 3. Customer grouping (no labels) | Unsupervised — Clustering |
# | 4. Too many columns | Unsupervised — Dimensionality Reduction |
# | 5. Delivery robot | Reinforcement Learning |
# | 6a. Loan repay/default | Supervised — Classification |
# | 6b. Customer grouping (pre-loan-label step) | Unsupervised — Clustering |
#
# If any of yours don't match, go back to `theory.md` Section 1 and re-check: *does this scenario have a labeled "correct answer" for every past example, or not? And if it does, is that answer a category or a number?* That one question resolves every case above.
